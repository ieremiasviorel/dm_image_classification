# %%
import sys
from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)

sys.path.append('/content/gdrive/My Drive/dm_image_classification')
# Out:
# Mounted at /content/gdrive

# %%
from classification._02_mobile_net import MobileNetClassifier

classifier = MobileNetClassifier()

classifier.preprocess_data()
classifier.train()
classifier.plot_history()
classifier.plot_confusion_matrix()
classifier.classify_random_images()
classifier.save_model()

# %%
from classification._03_mobile_net_v2 import MobileNetV2Classifier

classifier = MobileNetV2Classifier()

classifier.preprocess_data()
classifier.train()
classifier.plot_history()
classifier.plot_confusion_matrix()
classifier.classify_random_images()
classifier.save_model()

# %%
from classification._04_inception_net import InceptionNetClassifier

classifier = InceptionNetClassifier()

classifier.preprocess_data()
classifier.train()
classifier.plot_history()
classifier.plot_confusion_matrix()
classifier.classify_random_images()
classifier.save_model()

# %%
from classification._05_dense_net import DenseNetClassifier

classifier = DenseNetClassifier()

classifier.preprocess_data()
classifier.train()
classifier.plot_history()
classifier.plot_confusion_matrix()
classifier.classify_random_images()
classifier.save_model()

# %%
from classification._06_vgg16_net import VGG16NetClassifier

classifier = VGG16NetClassifier()

classifier.preprocess_data()
classifier.train()
classifier.plot_history()
classifier.plot_confusion_matrix()
classifier.classify_random_images()
classifier.save_model()

# %%
from classification._07_vgg19_net import VGG19NetClassifier

classifier = VGG19NetClassifier()

classifier.preprocess_data()
classifier.train()
classifier.plot_history()
classifier.plot_confusion_matrix()
classifier.classify_random_images()
classifier.save_model()

# %%
from classification._08_nas_net_large import NAsNetLargeClassifier

classifier = NAsNetLargeClassifier()

classifier.preprocess_data()
classifier.train()
classifier.plot_history()
classifier.plot_confusion_matrix()
classifier.classify_random_images()
classifier.save_model()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# ...
# 343613440/343610240 [==============================] - 8s 0us/step
# 0 input_10
# 1 stem_conv1
# 2 stem_bn1
# 3 activation_204
# 4 reduction_conv_1_stem_1
# 5 reduction_bn_1_stem_1
# 6 activation_205
# 7 activation_207
# 8 separable_conv_1_pad_reduction_left1_stem_1
# 9 separable_conv_1_pad_reduction_right1_stem_1
# 10 separable_conv_1_reduction_left1_stem_1
# 11 separable_conv_1_reduction_right1_stem_1
# 12 separable_conv_1_bn_reduction_left1_stem_1
# 13 separable_conv_1_bn_reduction_right1_stem_1
# 14 activation_206
# 15 activation_208
# 16 separable_conv_2_reduction_left1_stem_1
# 17 separable_conv_2_reduction_right1_stem_1
# 18 activation_209
# 19 separable_conv_2_bn_reduction_left1_stem_1
# 20 separable_conv_2_bn_reduction_right1_stem_1
# ...
